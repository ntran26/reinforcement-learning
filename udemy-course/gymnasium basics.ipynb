# %%
import gymnasium as gym

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array")
obs, info = env.reset()
print(f"obs: {obs}")
print(f"info: {info}")
G = 0

# terminated means the same thing as "done"
terminated = False
truncated = False
while not terminated and not truncated:
    action = env.action_space.sample()
    obs, reward, terminated, truncated, info = env.step(action)
    G += reward

# close environment
env.close()
print(f"Return = {G}")
# Out:
# obs: [-0.00843758 -0.03850624  0.04297459 -0.01694613]
# info: {}
# Return = 15.0

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array")
env = gym.wrappers.RecordVideo(env, "Videos")
obs, info = env.reset()
print(f"obs: {obs}")
print(f"info: {info}")
G = 0

# terminated means the same thing as "done"
terminated = False
truncated = False
while not terminated and not truncated:
    action = env.action_space.sample()
    obs, reward, terminated, truncated, info = env.step(action)
    G += reward

# close environment
env.close()
print(f"Return = {G}")
# Out:
# obs: [ 0.00376196 -0.01506055  0.03911991 -0.01539295]
# info: {}
# Moviepy - Building video c:\Users\hntran\OneDrive - University of Tasmania\Documents\PhD\reinforcement-learning\udemy-course\Videos\rl-video-episode-0.mp4.
# Moviepy - Writing video c:\Users\hntran\OneDrive - University of Tasmania\Documents\PhD\reinforcement-learning\udemy-course\Videos\rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready c:\Users\hntran\OneDrive - University of Tasmania\Documents\PhD\reinforcement-learning\udemy-course\Videos\rl-video-episode-0.mp4
# Return = 17.0

# %%
# !ls Videos/
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from IPython.display import HTML
from base64 import b64encode

mp4 = open('Videos/rl-video-episode-0.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
     <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#      <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
